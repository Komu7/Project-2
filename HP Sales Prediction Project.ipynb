# %% [markdown]
# # TASK : To predict the price of a home

# %%
! python -m pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in c:\users\leah\anaconda3\lib\site-packages (20.2.3)

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
from scipy import stats
from scipy.stats import norm,skew

# %% [markdown]
# # Exploratory data analysis

# %%
#load the data set
df=pd.read_csv('HP data.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#info about dataset
#Shows what kind of data types are our variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# For each numeric variable compute summary statistics
#statistical summary of data
df.describe().transpose()
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
#For all numeric variables, find the correlation
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %% [markdown]
# # Linear Regression

# %%
#Divide the data into train and validation
#x-columns inserted to be used as predictions
#y-target variables that will be predicted by x features

X=df.drop('SalePrice',axis=1).values
y=df['SalePrice'].values

#Dividing train and validation
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#Using simple linear regression build a model on training data
#visualizing wthe rshp btwn both variables to determine if linear
#using the column('OverallQual')because it is highly correlated to Sales Price
f, ax=plt.subplots(figsize=(10,8))
sns.regplot(x='SalePrice',y='OverallQual',data=df)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='OverallQual'>

# %% [markdown]
# #It is clear they both share a linear relationship with some outliers

# %%
#fitting our line into the data set to find value of m and c
feature_cols=['OverallQual']
X=df[feature_cols]
y=df.SalePrice

reg=LinearRegression()
hp=reg.fit(X, y)

print(hp.intercept_)
print(hp.coef_)
# Out:
# -96206.07951476044
# [45435.8025931]

# %% [markdown]
# #Line fitting the coefficients is
# y=45435x-96206

# %%
#Now on validation data, predict the sale-price and compute Mean absolute error
from sklearn import metrics
from sklearn import ensemble
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error, r2_score

predictions=reg.predict(X_test)

metrics.mean_absolute_error(y_test,predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2c0da0f24096> in <module>
#       5 from sklearn.metrics import mean_squared_error, r2_score
#       6
# ----> 7 predictions=reg.predict(X_test)
#       8
#       9 metrics.mean_absolute_error(y_test,predictions)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
# ...

# %%
from sklearn.model_selection import GridSearchCV
score_calc='neg_mean_absolute_error'
score_calc

# %%
#  Identify the important variables
df_quantitative=df[[d for d in d.columns if d.dtypes[d] !='object']]

# %% [markdown]
# # Ridge and Lasso Regression

# %% [markdown]
# Ridge

# %%
#Divide into train and validation
from sklearn.linear_model import Ridge
rr=Ridge(alpha=0.01)
rr.fit(X_train, y_train)
pred_train_rr=rr.predict(X_train)

# %%
#uild a model on training data
#use of gridsearchcv


ridge=Ridge()
parameters={'alpha':1e-15,1e-10,1e-8,1e-4}

ridge_regressor=GridSearch(ridge,parameters,scoring='neg_mean_squared_error',cv=)
ridge_regressor.fit(Xs,y)

# %%
##Now on validation data, predict the sale-price and compute Mean absolute error
pred_test_rr=rr.predict(X_test)
print(np.aqrt(mean_absolute_error(y_test,pred_test_rr)))
print(r2_score(y_test,pred_test_rr))

# %% [markdown]
# Lasso

# %%
#Divide into train and validation
from sklearn.linear_model import Lasso

model_lasso=lasso(alpha=0.01)
model_lasso.fit(X_train,y_train)
pred_train_lasso=model_lasso.predict(X_train)

# %%
#uild a model on training data

lasso=Lasso()
parameters={'alpha':1e-15,1e-10,1e-8,1e-4}

lasso_regressor=GridSearch(lasso,parameters,scoring='neg_mean_squared_error',cv=)
lasso_regressor.fit(Xs,y)

# %%
###Now on validation data, predict the sale-price and compute Mean absolute error
pred_test_lasso=model_lasso.predict(X_test)
print(np.sqrt(mean_squared-error(y_test,pred_test_lasso)))
print(r2_score(y_test,pred_test_lasso))
